# %% [markdown]
# <a href="https://colab.research.google.com/github/Park-Joyeong/hongong-machine-learning/blob/main/07_2_%EC%8B%AC%EC%B8%B5_%EC%8B%A0%EA%B2%BD%EB%A7%9D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import keras
(train_input, train_target), (test_input, test_target) =\
    keras.datasets.fashion_mnist.load_data()
# Out:
# ...
# 29515/29515 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# ...
# 26421880/26421880 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# ...
# 5148/5148 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# ...
# 4422102/4422102 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
from sklearn.model_selection import train_test_split

train_scaled = train_input / 255.0
train_scaled = train_scaled.reshape(-1, 28*28)
train_scaled, val_scaled, train_target, val_target = train_test_split(
    train_scaled, train_target, test_size=0.2, random_state=42
)

# %%
inputs = keras.layers.Input(shape=(784,))
dense1 = keras.layers.Dense(100, activation='sigmoid')
dense2 = keras.layers.Dense(10, activation='softmax')

# %%
model = keras.Sequential([inputs, dense1, dense2])

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 100)            │        78,500 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │         1,010 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 79,510 (310.59 KB)
#  Trainable params: 79,510 (310.59 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model = keras.Sequential([
    keras.layers.Input(shape=(784,)),
    keras.layers.Dense(100, activation='sigmoid', name='은닉층'),
    keras.layers.Dense(10, activation='softmax', name='출력층')
], name='패션 MNIST 모델')

# %%
model.summary()
# Out:
# Model: "패션 MNIST 모델"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ 은닉층 (Dense)                  │ (None, 100)            │        78,500 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ 출력층 (Dense)                  │ (None, 10)             │         1,010 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 79,510 (310.59 KB)
#  Trainable params: 79,510 (310.59 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model = keras.Sequential()
model.add(keras.layers.Input(shape=(784,)))
model.add(keras.layers.Dense(100, activation='sigmoid'))
model.add(keras.layers.Dense(10, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_2 (Dense)                 │ (None, 100)            │        78,500 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 10)             │         1,010 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 79,510 (310.59 KB)
#  Trainable params: 79,510 (310.59 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.fit(train_scaled, train_target, epochs=5)
# Out:
# Epoch 1/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.8055 - loss: 0.5680
# Epoch 2/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8515 - loss: 0.4122
# Epoch 3/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8626 - loss: 0.3769
# Epoch 4/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.8721 - loss: 0.3530
# Epoch 5/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8771 - loss: 0.3356

# %%
model = keras.Sequential()
model.add(keras.layers.Input(shape=(28,28)))
model.add(keras.layers.Flatten())
model.add(keras.layers.Dense(100, activation='relu'))
model.add(keras.layers.Dense(10, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)               │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 100)            │        78,500 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 10)             │         1,010 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 79,510 (310.59 KB)
#  Trainable params: 79,510 (310.59 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
(train_input, train_target), (test_input, test_target) =\
    keras.datasets.fashion_mnist.load_data()
train_scaled = train_input / 255.0
train_scaled, val_scaled, train_target, val_target = train_test_split(
    train_scaled, train_target, test_size=0.2, random_state=42
)

# %%
model.compile(loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.fit(train_scaled, train_target, epochs=5)
# Out:
# Epoch 1/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8124 - loss: 0.5300
# Epoch 2/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8572 - loss: 0.3959
# Epoch 3/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8722 - loss: 0.3580
# Epoch 4/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8791 - loss: 0.3361
# Epoch 5/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8852 - loss: 0.3191

# %%
model.evaluate(val_scaled, val_target)
# Out:
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8765 - loss: 0.3628
# [0.362833172082901, 0.8765000104904175]

# %%
model = keras.Sequential()
model.add(keras.layers.Input(shape=(28,28)))
model.add(keras.layers.Flatten())
model.add(keras.layers.Dense(100, activation='relu'))
model.add(keras.layers.Dense(10, activation='softmax'))

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.fit(train_scaled, train_target, epochs=5)
# Out:
# Epoch 1/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8162 - loss: 0.5256
# Epoch 2/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8585 - loss: 0.3954
# Epoch 3/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8730 - loss: 0.3519
# Epoch 4/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8804 - loss: 0.3267
# Epoch 5/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8868 - loss: 0.3078

# %%
model.evaluate(val_scaled, val_target)
# Out:
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8726 - loss: 0.3676
# [0.3676120638847351, 0.8725833296775818]

# %% [markdown]
# # 파이토치 버전 살펴보기

# %%
from torchvision.datasets import FashionMNIST

fm_train = FashionMNIST(root='.', train=True, download=True)
fm_test = FashionMNIST(root='.', train=False, download=True)
# Out:
# 100%|██████████| 26.4M/26.4M [00:02<00:00, 13.0MB/s]
# 100%|██████████| 29.5k/29.5k [00:00<00:00, 204kB/s]
# 100%|██████████| 4.42M/4.42M [00:01<00:00, 3.82MB/s]
# 100%|██████████| 5.15k/5.15k [00:00<00:00, 14.0MB/s]

# %%
type(fm_train.data)
# Out:
# torch.Tensor

# %%
print(fm_train.data.shape, fm_test.data.shape)
# Out:
# torch.Size([60000, 28, 28]) torch.Size([10000, 28, 28])

# %%
print(fm_train.targets.shape, fm_test.targets.shape)
# Out:
# torch.Size([60000]) torch.Size([10000])

# %%
train_input = fm_train.data
train_target = fm_train.targets

# %%
# 입력 정규화
train_scaled = train_input / 255.0

# %%
from sklearn.model_selection import train_test_split

train_scaled, val_scaled, train_target, val_target = train_test_split(
    train_scaled, train_target, test_size=0.2, random_state=42
)

# %%
print(train_scaled.shape, val_scaled.shape)
# Out:
# torch.Size([48000, 28, 28]) torch.Size([12000, 28, 28])

# %%
import torch.nn as nn

model = nn.Sequential(
    nn.Flatten(),
    nn.Linear(784, 100),
    nn.ReLU(),
    nn.Linear(100, 10)
)

# %%
# !pip install torchinfo

# %%
from torchinfo import summary

summary(model, input_size=(32, 28, 28))
# Out:
# ...
# Layer (type:depth-idx)                   Output Shape              Param #
# ...
# Sequential                               [32, 10]                  --
# ├─Flatten: 1-1                           [32, 784]                 --
# ├─Linear: 1-2                            [32, 100]                 78,500
# ├─ReLU: 1-3                              [32, 100]                 --
# ├─Linear: 1-4                            [32, 10]                  1,010
# ...
# Total params: 79,510
# Trainable params: 79,510
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 2.54
# ...
# Input size (MB): 0.10
# Forward/backward pass size (MB): 0.03
# Params size (MB): 0.32
# Estimated Total Size (MB): 0.45
# ...

# %%
import torch

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
# Out:
# Sequential(
#   (0): Flatten(start_dim=1, end_dim=-1)
#   (1): Linear(in_features=784, out_features=100, bias=True)
#   (2): ReLU()
#   (3): Linear(in_features=100, out_features=10, bias=True)
# )

# %%
import torch.optim as optim

criterion = nn.CrossEntropyLoss()  # criterion: 기준
optimizer = optim.Adam(model.parameters())

# %%
epochs = 5
batches = int(len(train_scaled) / 32)
for epoch in range(epochs):
    model.train()  # 모델을 훈련 모드로 설정한다.
    train_loss = 0  # 현재 에포크의 전체 손실을 저장할 변수를 0으로 초기화한다.
    for i in range(batches):
        inputs = train_scaled[i*32:(i+1)*32].to(device)  # 입력 데이터 32개를 꺼내 GPU/CPU로 이동한다.
        targets = train_target[i*32:(i+1)*32].to(device)  # 해당 입력의 정답 32개를 GPU/CPU로 이동한다.
        optimizer.zero_grad()  # 이전 배치에서 계산된 gradient를 0으로 초기화한다.
        outputs = model(inputs)  # 입력 데이터를 모델에 넣어 예측값을 계산한다.
        loss = criterion(outputs, targets)  # 예측값과 실제 정답을 비교하여 손실을 계산한다.
        loss.backward()  # 손실을 기준으로 각 가중치의 gradient를 계산한다.
        optimizer.step()  # 계산된 gradient를 이용해 가중치를 업데이트한다.
        train_loss += loss.item()  # 현재 배치의 손실값을 누적한다.
    print(f"에포크:{epoch + 1}, 손실:{train_loss/batches:.4f}")
# Out:
# 에포크:1, 손실:0.5457
# 에포크:2, 손실:0.4040
# 에포크:3, 손실:0.3601
# 에포크:4, 손실:0.3315
# 에포크:5, 손실:0.3112

# %%
model.eval()  # 모델을 평가 모드로 설정한다.
with torch.no_grad():  # 평가할 때 gradient를 계산하지 않도록 한다.
    val_scaled = val_scaled.to(device)  # 검증 입력 데이터를 GPU/CPU로 이동한다.
    val_target = val_target.to(device)  # 검증 정답 데이터를 GPU/CPU로 이동한다.
    outputs = model(val_scaled)  # 검증 데이터를 모델에 넣어 예측값을 계산한다.
    predicts = torch.argmax(outputs, 1)  # 각 샘플에서 가장 큰 출력값을 가진 클래스 번호를 선택한다.
    corrects = (predicts == val_target).sum().item()  # 예측과 정답이 같은 샘플의 개수를 센다.

accuracy = corrects / len(val_target)
print(f"정확도: {accuracy:.4f}")
# Out:
# 정확도: 0.8728
